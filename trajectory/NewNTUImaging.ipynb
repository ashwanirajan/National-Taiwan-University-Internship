# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab
import pandas as pd

# %%
## Read binary data
data = np.fromfile('data_p1.bin',dtype='double')  
## Reshape the array
data = np.reshape(data,(120,3))
data_df = pd.DataFrame(data, columns = ["x","y","z"])
data_df.to_csv("actual_data.csv")

# %%
data1 = np.array(data)
#print(data1)
## visualize the 2D array
fig = plt.figure(1)
ax = fig.add_subplot(111, axisbg='black')
#pylab.ylim([0,520])
#pylab.xlim([0,520])
ax.scatter(data1[:,0], data1[:,1], c = "white")
plt.savefig('img.png')
fig.canvas.draw()
plt.show()
