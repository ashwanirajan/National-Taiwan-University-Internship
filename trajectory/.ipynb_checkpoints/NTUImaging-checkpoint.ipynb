# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("data_final_3.csv")

data.head()
# Out:
#             X           Y           Z
# 0  256.093170  256.000000  256.000000
# 1  256.279463  256.002709  255.999998
# 2  256.558757  256.010822  255.999988
# 3  256.930862  256.027037  255.999965
# 4  257.395506  256.054048  255.999919

# %%
fig = plt.figure(1, figsize = (20,20))
ax = fig.add_subplot(111, facecolor='black')
#pylab.ylim([0,520])
#pylab.xlim([0,520])
for i in range(len(data)):
    ax.scatter(data.X[:i], data.Y[:i], s = 5, c = "white")
    ax.grid(False)
    plt.ylim(ymax = 1256, ymin = -1000+256)
    plt.xlim(xmax = 1256, xmin = -1000+256)
    plt.savefig('img_%d.png'%(i,))
    fig.canvas.draw()
    #plt.show()
